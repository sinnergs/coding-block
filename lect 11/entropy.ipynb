# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#entropy = sum of (probability*logbase2(prob))    for all factors

# %%
y= []
for i in range(1,50):
    red = i
    black = 50-i
    
    entropy = -((red/50)*np.log2(red/50) + (blvcsbvsvvack/50)*np.log2(black/50))
    y.append(entropy)
    
plt.plot(y)
